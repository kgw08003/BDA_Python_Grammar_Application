# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('wine_test.csv')
df
# Out:
#      Unnamed: 0  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0             0    14.23        1.71  2.43               15.6        127
# 1             1      NaN        1.78  2.14               11.2        100
# 2             2    13.16        2.36  2.67               18.6        101
# 3             3    14.37        1.95  2.50               16.8        113
# 4             4    13.24        2.59  2.87               21.0        118
# ..          ...      ...         ...   ...                ...        ...
# 173         173    13.71        5.65  2.45               20.5         95
# 174         174    13.40        3.91  2.48               23.0        102
# 175         175    13.27        4.28  2.26               20.0        120
# 176         176    13.17        2.59  2.37               20.0        120
# 177         177    14.13        4.10  2.74               24.5         96
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# ...

# %%
df = df[[ 'alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash',
       'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
       'proanthocyanins', 'color_intensity', 'hue',
       'od280/od315_of_diluted_wines', 'proline', 'class']]

# %% [markdown]
# ### 필수과제 3
# - 아래에 나온 스케일링을 모두 다 진행하여 값들의 변화를 확인하고
# - 어떤 기준으로 스케일링을 진행해야 하는지 종합적으로 판단하여 결론 주석처리 해주세요!

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
#먼저 예시로 스케일링이 어떤 식으로 되는지?
st_scaler = StandardScaler()
mm_scaler = MinMaxScaler()

# %%
df_m=np.array(df['magnesium'])

# %%
df_m=df_m.reshape(-1,1)

# %%
st_scaler.fit(df_m) #fit함수를 넣어서 진행
mm_scaler.fit(df_m)
# Out:
# MinMaxScaler()

# %%
df_m_sc= st_scaler.transform(df_m)
df_m_mm= mm_scaler.transform(df_m)

# %%
df_m
# Out:
# array([[127],
#        [100],
#        [101],
#        [113],
#        [118],
#        [112],
#        [ 96],
#        [121],
#        [ 97],
#        [ 98],
#        [105],
#        [ 95],
#        [ 89],
#        [ 91],
#        [102],
#        [112],
#        [120],
#        [115],
#        [108],
#        [116],
#        [126],
#        [102],
#        [101],
#        [ 95],
#        [ 96],
#        [124],
#        [ 93],
#        [ 94],
#        [107],
#        [ 96],
#        [101],
#        [106],
#        [104],
#        [132],
#        [110],
#        [100],
#        [110],
#        [ 98],
#        [ 98],
#        [128],
#        [117],
#        [ 90],
#        [101],
#        [103],
#        [107],
#        [111],
#        [102],
#        [101],
#        [103],
#        [108],
#        [ 92],
#        [ 94],
#        [111],
#        [115],
#        [118],
#        [116],
#        [118],
#        [102],
#        [108],
#        [ 88],
#        [101],
#        [100],
# ...

# %%
df_m_sc
# Out:
# array([[ 1.91390522],
#        [ 0.01814502],
#        [ 0.08835836],
#        [ 0.93091845],
#        [ 1.28198515],
#        [ 0.86070511],
#        [-0.26270834],
#        [ 1.49262517],
#        [-0.192495  ],
#        [-0.12228166],
#        [ 0.36921172],
#        [-0.33292168],
#        [-0.75420173],
#        [-0.61377505],
#        [ 0.1585717 ],
#        [ 0.86070511],
#        [ 1.42241183],
#        [ 1.07134513],
#        [ 0.57985175],
#        [ 1.14155847],
#        [ 1.84369188],
#        [ 0.1585717 ],
#        [ 0.08835836],
#        [-0.33292168],
#        [-0.26270834],
#        [ 1.7032652 ],
#        [-0.47334836],
#        [-0.40313502],
#        [ 0.50963841],
#        [-0.26270834],
#        [ 0.08835836],
#        [ 0.43942506],
#        [ 0.29899838],
#        [ 2.26497192],
#        [ 0.72027843],
#        [ 0.01814502],
#        [ 0.72027843],
#        [-0.12228166],
#        [-0.12228166],
#        [ 1.98411856],
#        [ 1.21177181],
# ...

# %%
df_m_mm
# Out:
# array([[0.61956522],
#        [0.32608696],
#        [0.33695652],
#        [0.4673913 ],
#        [0.52173913],
#        [0.45652174],
#        [0.2826087 ],
#        [0.55434783],
#        [0.29347826],
#        [0.30434783],
#        [0.38043478],
#        [0.27173913],
#        [0.20652174],
#        [0.22826087],
#        [0.34782609],
#        [0.45652174],
#        [0.54347826],
#        [0.48913043],
#        [0.41304348],
#        [0.5       ],
#        [0.60869565],
#        [0.34782609],
#        [0.33695652],
#        [0.27173913],
#        [0.2826087 ],
#        [0.58695652],
#        [0.25      ],
#        [0.26086957],
#        [0.40217391],
#        [0.2826087 ],
#        [0.33695652],
#        [0.39130435],
#        [0.36956522],
#        [0.67391304],
#        [0.43478261],
#        [0.32608696],
#        [0.43478261],
#        [0.30434783],
#        [0.30434783],
#        [0.63043478],
#        [0.51086957],
#        [0.2173913 ],
#        [0.33695652],
# ...

# %%
df['magnesium'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 더 좋은 값을 찾기 위해서는 예측의 평가지표로 확인한다.
# - 머신러닝은 결국 정답레이블에 대한 예측을 평가하니깐
